# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.array(Image.open(r'C:\Users\romai\Documents\FreezingEffect\src\freezingeffect\alignment\aligned\2023-04-06_T_FRE-FR-T0_FR_S3_1__30_06_2023_17_33_14\invReg\mask_PrpgTo_2023-06-30_T_FRE-FR-T1_FR_S3_1_550nm_realsize_AffineElastic_TransformParameters_1.png'))

# %%
img_gs = np.array(Image.open(r'F:\ImpactHistology\Freezing_dev\2023-06-30_T_FRE-FR-T1_FR_S3_1\polarimetry\550nm\2023-06-30_T_FRE-FR-T1_FR_S3_1_550nm_realsize.png'))

# %%
for idx, x in enumerate(img):
    for idy, y in enumerate(x):
        if y != 0:
            # if y > 0 and y <= 25:
            if y > 25:
                img_gs[idx, idy] = 0
                
plt.imshow(img_gs)
